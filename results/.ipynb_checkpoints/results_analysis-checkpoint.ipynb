# %%
from datetime import datetime
from datetime import timedelta

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import os
import json
from tqdm.notebook import tqdm
import plotly.express as px
import plotly

from comet_ml import Experiment

# %%
with open('../config/config.json', 'r') as file:
    config = json.load(file)
    
with open('../config/config_emb_path.json', 'r') as file:
    config_emb = json.load(file)
    
rs = config['random_state']

# %%
def change_features(df):
    df['AVG_returns'] = (df['AVG_returns'] + 1) ** 252 - 1
    df['Risk'] = (df['Risk'] + 1) ** np.sqrt(252) - 1
    df['Alpha'] = df['Alpha'].round(4)
    df['Drawdown'] = -df['Drawdown']
    

    return df

# %% [markdown]
# # Building table

# %%
year_start = 2020
fine_tune = True

# %%
def filter_risk_return(df, filter_baselines=['sp500', 'sectors'], save_methods=['sectors', 'sp500']):      
        
    for baseline in filter_baselines:

        risk_baseline = df[df.emb_model == baseline]['Risk'].values[0]
        mask_risk = df['Risk'] <= risk_baseline
        mask = mask_risk

        return_baseline = df[df.emb_model == baseline]['AVG_returns'].values[0]
        mask_return = df['AVG_returns'] >= return_baseline
        mask = mask & mask_return
        
        drd_baseline = df[df.emb_model == baseline]['Drawdown'].values[0]
        mask_drd = df['Drawdown'] <= drd_baseline
        mask = mask & mask_drd
        
        mask_save = df['emb_model'].isin(save_methods)
        mask = mask | mask_save

        df = df[mask]
        
    mask_save = df['emb_model'].isin(save_methods)
    df = df[(df['AVG_returns'] > 0) | mask_save]
    return df.sort_values('Sharpe', ascending=False)

# %%
config['financial_metric_path'].format(year_start, fine_tune)
# Out:
# 'results/financial_metric_2020_True.csv'

# %%
financial_metrics = {year_start:pd.read_csv('../'+config['financial_metric_path'].format(year_start, fine_tune), index_col=0) 
                     for year_start in [2020, 2021]}

# %%
df_2020 = pd.read_csv('../'+config['financial_metric_path'].format(2020, False), index_col=0)
df_2020_tuned = pd.read_csv('../'+config['financial_metric_path'].format(2020, True), index_col=0)
df_2021 = pd.read_csv('../'+config['financial_metric_path'].format(2021, False), index_col=0)

df_2020 = change_features(df_2020)
df_2020_tuned = change_features(df_2020_tuned)
df_2021 = change_features(df_2021)

# %%
df_2020_filtered = filter_risk_return(df_2020, filter_baselines=['sectors'], 
                                      save_methods=['sectors', 'sp500'])

# %%
df_2020_filtered_tuned = filter_risk_return(df_2020_tuned, filter_baselines=['sectors'], 
                                      save_methods=['sectors', 'sp500'])
df_2020_filtered_tuned
# Out:
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.606091  0.355021  0.674516  0.0017  0.091323 -0.031883  24.775282
# port     0.508435  0.319754  0.716834  0.0014  0.085943 -0.029091  32.473692
# port     0.404480  0.324876  0.747942  0.0011  0.068878 -0.029501  36.530910
# port     0.464832  0.377153  0.635457  0.0013  0.068685 -0.033600  33.899962
# port     0.457139  0.375732  0.662357  0.0013  0.067878 -0.033491  37.609756
# port     0.394508  0.324655  0.761980  0.0011  0.067334 -0.029483  32.822206
# port     0.393651  0.333660  0.660439  0.0011  0.065602 -0.030200  37.237865
# port     0.381320  0.323331  0.743312  0.0011  0.065456 -0.029378  29.859144
# port     0.405292  0.346878  0.705258  0.0011  0.065156 -0.031244  33.048880
# port     0.404731  0.356168  0.696695  0.0011  0.063590 -0.031973  35.514546
# port     0.420422  0.372577  0.678789  0.0012  0.063342 -0.033247  31.765110
# port     0.418929  0.376816  0.642837  0.0012  0.062520 -0.033574  34.045320
# port     0.350557  0.343130  0.696339  0.0010  0.057361 -0.030949  34.166709
# port     0.352284  0.355779  0.687188  0.0010  0.055841 -0.031942  38.912704
# port     0.357298  0.362383  0.709086  0.0010  0.055702 -0.032457  34.526624
# port     0.350680  0.362683  0.673725  0.0010  0.054676 -0.032480  40.247957
# port     0.345204  0.385629  0.605734  0.0010  0.051072 -0.034251  42.313929
# port     0.068939  0.288985  1.000000  0.0000  0.009137 -0.026598  33.924960
#
#       Recovery clust_model                      emb_model
# port      57.0      KMeans                takens_one_PL_2
# port      55.0      KMeans  takens_mult_PI_2_sigma=0.0005
# port      91.0      KMeans         table_finance_features
# port      82.0      KMeans                takens_one_BC_1
# port     122.0      KMeans               autoencoder_lstm
# port      82.0      KMeans   takens_one_PI_2_sigma=0.0005
# port     100.0      KMeans   takens_one_PI_1_sigma=0.0005
# port     108.0      KMeans               takens_mult_PL_2
# port     145.0      KMeans       transformer_embds_sum_23
# port     115.0      KMeans                takens_one_BC_2
# port     180.0      KMeans             transformer_embds3
# port      72.0      KMeans               takens_mult_BC_0
# port     180.0         Agg             transformer_embds3
# port      70.0      KMeans             transformer_embds1
# port     181.0      KMeans                takens_one_PL_1
# port     132.0      KMeans               takens_mult_BC_1
# port     185.0     sectors                        sectors
# port     179.0       sp500                          sp500

# %%
df_2021_filtered = filter_risk_return(df_2021, filter_baselines=['sectors'], 
                                      save_methods=['sectors', 'sp500'])
df_2021_filtered
# Out:
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.672739  0.270982  0.501459  0.0021  0.126564 -0.025113  12.020327
# port     0.414883  0.208473  0.605803  0.0014  0.105069 -0.019800  11.293906
# port     0.491682  0.315458  0.468096  0.0016  0.084426 -0.028746  16.850101
# port     0.354555  0.328862  0.421275  0.0012  0.060186 -0.029819  20.176808
# port    -0.042238  0.203246  1.000000  0.0000 -0.024612 -0.019344  25.081503
#
#       Recovery clust_model               emb_model
# port      65.0      KMeans  table_finance_features
# port      78.0         Agg  table_finance_features
# port      73.0         Agg                 tsfresh
# port      88.0     sectors                 sectors
# port     179.0       sp500                   sp500

# %%
df_2020_tuned[df_2020_tuned.clust_model != 'KMeans']
# Out:
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.191167  0.363129  0.640662  0.0005  0.029286 -0.032515  36.463147
# port    -0.065147  0.247098  0.941967 -0.0005 -0.027456 -0.023112  31.130780
# port     0.156138  0.317826  0.740148  0.0003  0.026150 -0.028937  28.214303
# port     0.330917  0.359422  0.667278  0.0009  0.052108 -0.032227  36.297709
# port     0.350557  0.343130  0.696339  0.0010  0.057361 -0.030949  34.166709
# port     0.356413  0.411002  0.583410  0.0010  0.049856 -0.036178  41.246102
# port     0.102995  0.327738  0.691486  0.0002  0.015084 -0.029729  43.476745
# port     0.261016  0.375108  0.585676  0.0007  0.039640 -0.033443  39.231977
# port     0.064499  0.327195  0.737279  0.0000  0.007268 -0.029686  41.084186
# port     0.165177  0.430370  0.574173  0.0004  0.021467 -0.037626  43.611548
# port     0.016286  0.354625  0.562724 -0.0001 -0.002756 -0.031852  47.480629
# port     0.031469  0.372371  0.663279 -0.0001  0.000281 -0.033231  49.544986
# port     0.167550  0.327986  0.744093  0.0004  0.027599 -0.029749  34.305340
# port     0.077526  0.439310  0.525513  0.0001  0.007715 -0.038289  49.992064
# port     0.281739  0.430928  0.522361  0.0008  0.038029 -0.037668  41.064541
# port     0.022259  0.261434  0.847963 -0.0002 -0.002031 -0.024317  33.704600
# port     0.230659  0.378232  0.573631  0.0006  0.034615 -0.033683  33.534508
# port    -0.079744  0.260541  0.838898 -0.0006 -0.030425 -0.024243  39.033371
# port     0.110263  0.300683  0.769028  0.0002  0.017837 -0.027552  27.202189
# port     0.017194  0.289219  0.809413 -0.0002 -0.003078 -0.026617  36.429393
# port     0.065112  0.267004  0.835112  0.0000  0.008858 -0.024782  35.129615
# port     0.140466  0.287962  0.760145  0.0003  0.025167 -0.026514  35.288474
# port    -0.044724  0.279005  0.844306 -0.0004 -0.019130 -0.025777  37.128478
# port     0.042932  0.314650  0.766463 -0.0001  0.002849 -0.028681  42.729693
# port     0.230659  0.378232  0.573631  0.0006  0.034615 -0.033683  33.534508
# port     0.118801  0.346906  0.723935  0.0002  0.017334 -0.031247  39.074432
# port     0.017218  0.269257  0.880078 -0.0002 -0.003275 -0.024970  37.278464
# port     0.254840  0.447228  0.551343  0.0007  0.033275 -0.038872  41.850209
# port     0.108661  0.401834  0.619014  0.0002  0.013583 -0.035485  47.793661
# port     0.248957  0.359521  0.652666  0.0007  0.039172 -0.032234  34.656744
# port     0.198398  0.307040  0.805021  0.0005  0.035340 -0.028068  36.844022
# port     0.014308  0.283063  0.782116 -0.0002 -0.003850 -0.026112  37.243089
# port     0.037729  0.341597  0.733370 -0.0001  0.001588 -0.030828  49.249316
# port     0.335218  0.372948  0.665099  0.0009  0.051100 -0.033276  33.954587
# port     0.209302  0.407082  0.638369  0.0005  0.029297 -0.035882  47.218338
# port     0.068939  0.288985  1.000000  0.0000  0.009137 -0.026598  33.924960
# port     0.345204  0.385629  0.605734  0.0010  0.051072 -0.034251  42.313929
#
#       Recovery       clust_model                      emb_model
# port     154.0               Agg                         ts2vec
# port     642.0               Agg                takens_one_BC_2
# port     182.0               Agg                takens_one_PL_2
# port     180.0               Agg       transformer_embds_sum_23
# port     180.0               Agg             transformer_embds3
# port     288.0               Agg             transformer_embds2
# port     219.0               Agg  takens_mult_PI_0_sigma=0.0005
# port     180.0               Agg               takens_mult_PL_2
# port     196.0               Agg                takens_one_BC_1
# port     148.0               Agg         table_finance_features
# port     492.0               Agg  takens_mult_PI_1_sigma=0.0005
# port     257.0               Agg               signal2vec_embds
# port     121.0               Agg                autoencoder_mlp
# port     179.0               Agg               takens_mult_PL_1
# port     317.0               Agg                        tsfresh
# port     199.0               Agg                takens_one_BC_0
# port     317.0               Agg                            pca
# port     654.0               Agg   takens_one_PI_0_sigma=0.0005
# port     260.0               Agg               autoencoder_conv
# port     316.0               Agg               takens_mult_BC_0
# port     285.0               Agg   takens_one_PI_2_sigma=0.0005
# port     129.0               Agg   takens_one_PI_1_sigma=0.0005
# port     635.0               Agg  takens_mult_PI_2_sigma=0.0005
# port     205.0               Agg                           umap
# port     317.0               Agg                        fastica
# port     108.0               Agg             transformer_embds1
# port     277.0               Agg               takens_mult_BC_2
# port     154.0               Agg                takens_one_PL_1
# port     207.0               Agg               autoencoder_lstm
# port     304.0               Agg      transformer_embds_sum_all
# port     152.0               Agg                           tnse
# port     266.0               Agg               takens_mult_BC_1
# port     239.0           MSTcorr                        MSTcorr
# port      93.0            KShape                         KShape
# port     209.0  TimeSeriesKMeans               TimeSeriesKMeans
# port     179.0             sp500                          sp500
# port     185.0           sectors                        sectors

# %%
dict_category2emb = {
    'topological' : ['takens_mult_BC_0',
 'takens_mult_BC_1',
 'takens_mult_BC_2',
 'takens_mult_PI_0_sigma=0.0005',
 'takens_mult_PI_1_sigma=0.0005',
 'takens_mult_PI_2_sigma=0.0005',
 'takens_mult_PL_1',
 'takens_mult_PL_2',
 'takens_one_BC_0',
 'takens_one_BC_1',
 'takens_one_BC_2',
 'takens_one_PI_0_sigma=0.0005',
 'takens_one_PI_1_sigma=0.0005',
 'takens_one_PI_2_sigma=0.0005',
 'takens_one_PL_1',
 'takens_one_PL_2',],
    
    'dim_reduction' : ['umap', 'pca', 'fastica', 'tnse'],
    
    'transformers' : [ 'transformer_embds1',
 'transformer_embds2',
 'transformer_embds3',
 'transformer_embds_sum_23',
 'transformer_embds_sum_all',],
    
    'autoencoders' : [ 'autoencoder_conv',
 'autoencoder_lstm',
 'autoencoder_mlp',],
    
    'baselines' : ['sp500', 'sectors'],
    
    'interpretable' : [ 'tsfresh', 'table_finance_features'],
    
    'time_clustering' : ['KShape',
 'MSTcorr',
 'TimeSeriesKMeans'],
    
    'time_embedding' : ['ts2vec', 'signal2vec_embds']
}

# %%
dict_emb2cat = {method:categ for categ, list_methods in dict_category2emb.items() for method in list_methods }
#dict_emb2cat

# %%
df_2020_clusters = pd.read_csv('../'+config['clust_metric_path'].format(2020, True), index_col=0)
df_2020_tuned = pd.merge(df_2020_clusters.drop(columns=['clust_model']), df_2020_tuned, on='emb_model', how='outer')

df_best_clustering = df_2020_tuned.sort_values(['Risk'], ascending=False)
df_best_clustering = df_best_clustering.groupby('emb_model', as_index=False, sort=True).first()
df_best_clustering['category'] = df_best_clustering['emb_model'].map(dict_emb2cat)
df_best_clustering.drop(columns=['Beta', 'Alpha', 'VaR']).to_csv('../results/table_all_methods.csv')

# %% [markdown]
# ## COMET_ML

# %%
year_start = 2020
fine_tune = True

for key in config_emb.keys():
    config_emb[key] = config_emb[key].format(year_start)

# %%
df_finance = pd.read_csv('../'+config['financial_metric_path'].format(year_start, fine_tune), index_col=0)
df_clust = pd.read_csv('../'+config['clust_metric_path'].format(year_start, fine_tune), index_col=0)

df_finance = change_features(df_finance)

# %%
df_finance.head()
# Out:
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.495915  0.411040  0.601512  0.0014  0.067593 -0.036180  43.955665
# port     0.191167  0.363129  0.640662  0.0005  0.029286 -0.032515  36.463147
# port     0.404731  0.356168  0.696695  0.0011  0.063590 -0.031973  35.514546
# port    -0.065147  0.247098  0.941967 -0.0005 -0.027456 -0.023112  31.130780
# port     0.606091  0.355021  0.674516  0.0017  0.091323 -0.031883  24.775282
#
#       Recovery clust_model        emb_model
# port      75.0      KMeans           ts2vec
# port     154.0         Agg           ts2vec
# port     115.0      KMeans  takens_one_BC_2
# port     642.0         Agg  takens_one_BC_2
# port      57.0      KMeans  takens_one_PL_2

# %%
model_del = 'Agg' if model_name == 'KMeans' else 'KMeans'

df_finance = df_finance[df_finance.clust_model != model_del]
df_clust = df_clust[df_clust.clust_model != model_del]

df_finance = df_finance.set_index('emb_model').drop(columns=['clust_model'])
df_clust = df_clust.set_index('emb_model').drop(columns=['clust_model'])

df_data = df_finance.join(df_clust)

assert len(df_data) == len(df_clust) + 1 == len(df_finance)
df_data.head()
# Out:
#                           AVG_returns      Risk      Beta   Alpha    Sharpe  \
# emb_model
# ts2vec                       0.191167  0.363129  0.640662  0.0005  0.029286
# takens_one_BC_2             -0.065147  0.247098  0.941967 -0.0005 -0.027456
# takens_one_PL_2              0.156138  0.317826  0.740148  0.0003  0.026150
# transformer_embds_sum_23     0.330917  0.359422  0.667278  0.0009  0.052108
# transformer_embds3           0.350557  0.343130  0.696339  0.0010  0.057361
#
#                                VaR   Drawdown  Recovery        DB          HC  \
# emb_model
# ts2vec                   -0.032515  36.463147     154.0  0.320173   18.543424
# takens_one_BC_2          -0.023112  31.130780     642.0  0.453790    6.411142
# takens_one_PL_2          -0.028937  28.214303     182.0  0.311802   10.268861
# transformer_embds_sum_23 -0.032227  36.297709     180.0  1.142738  130.819923
# transformer_embds3       -0.030949  34.166709     180.0  1.202075  129.118784
#
#                                Sil       hom
# emb_model
# ts2vec                    0.516730  0.028243
# takens_one_BC_2           0.273747  0.028900
# takens_one_PL_2           0.379736  0.023011
# transformer_embds_sum_23  0.216855  0.051649
# transformer_embds3        0.223701  0.054524

# %%
# for model_name, data in tqdm(df_model.iterrows()):
    
#     experiment = Experiment(
#     api_key="W4Exl5JlKMoVHRelfS04Tc0Lg",
#     project_name="stock-clustering-with-time-series-embeddings",
#     workspace="petrsokerin",
#     )

#     experiment.set_name(model_name)

#     hyper_params = {
#         "model": model_name,
#         "include_2020": year_start == 2021,
#         "fine_tune": fine_tune,
#     }

#     experiment.log_parameters(hyper_params)
    
#     print(model_name)
#     metrics = data.to_dict()
#     experiment.log_metrics(metrics)
